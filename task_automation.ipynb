# %% [markdown]
# Searching/analyzing data

# %%
# !pip install yfinance

import yfinance

ticker = input('Action code:')
dados = yfinance.Ticker(ticker)

dados.history()

table = dados.history("6mo")
table

#Select Close

close = table.Close
close

#Line graph
close.plot()

#Statistics
maximum = round(close.max(), 2)
minimum = round (close.min(),2)
nowadays = round (close[-1], 2)

print(maximum)
print(minimum)
print(nowadays)
# Out:
# Requirement already satisfied: yfinance in c:\users\amanda aiko\anaconda3\lib\site-packages (0.2.31)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\amanda aiko\anaconda3\lib\site-packages (from yfinance) (2.0.3)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\amanda aiko\anaconda3\lib\site-packages (from yfinance) (1.24.3)
# Requirement already satisfied: requests>=2.31 in c:\users\amanda aiko\anaconda3\lib\site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\amanda aiko\anaconda3\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\amanda aiko\anaconda3\lib\site-packages (from yfinance) (4.9.3)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\amanda aiko\anaconda3\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in c:\users\amanda aiko\anaconda3\lib\site-packages (from yfinance) (2023.3.post1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\amanda aiko\anaconda3\lib\site-packages (from yfinance) (2.3.8)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\amanda aiko\anaconda3\lib\site-packages (from yfinance) (3.17.0)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\amanda aiko\anaconda3\lib\site-packages (from yfinance) (4.12.2)
# Requirement already satisfied: html5lib>=1.1 in c:\users\amanda aiko\anaconda3\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\amanda aiko\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.4)
# Requirement already satisfied: six>=1.9 in c:\users\amanda aiko\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\amanda aiko\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\amanda aiko\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\amanda aiko\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\amanda aiko\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\amanda aiko\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\amanda aiko\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\amanda aiko\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2023.7.22)
# Action code:^BVSP
# 122560.0
# 101797.0
# 113155.0

# %% [markdown]
# Automating email sending

# %%
# !pip install pyautogui
# !pip install pyperclip

import pyautogui
import pyperclip

#Email
From = "amandaaiko3@hotmail.com"
Subject = "Action analysis"

Body = f"""
Good morning,

Below are the analysis of the action {ticker} of the last six months:

Maximum quote: R$ {round(maximum)}
Minimum quote: R$ {round(minimum)}
Current quote: R$ {round(nowadays)}

"""

print(From)
print(Subject)
print(Body)
# Out:
# Requirement already satisfied: pyautogui in c:\users\amanda aiko\anaconda3\lib\site-packages (0.9.54)
# Requirement already satisfied: pymsgbox in c:\users\amanda aiko\anaconda3\lib\site-packages (from pyautogui) (1.0.9)
# Requirement already satisfied: pytweening>=1.0.4 in c:\users\amanda aiko\anaconda3\lib\site-packages (from pyautogui) (1.0.7)
# Requirement already satisfied: pyscreeze>=0.1.21 in c:\users\amanda aiko\anaconda3\lib\site-packages (from pyautogui) (0.1.29)
# Requirement already satisfied: pygetwindow>=0.0.5 in c:\users\amanda aiko\anaconda3\lib\site-packages (from pyautogui) (0.0.9)
# Requirement already satisfied: mouseinfo in c:\users\amanda aiko\anaconda3\lib\site-packages (from pyautogui) (0.1.3)
# Requirement already satisfied: pyrect in c:\users\amanda aiko\anaconda3\lib\site-packages (from pygetwindow>=0.0.5->pyautogui) (0.2.0)
# Requirement already satisfied: pyscreenshot in c:\users\amanda aiko\anaconda3\lib\site-packages (from pyscreeze>=0.1.21->pyautogui) (3.1)
# Requirement already satisfied: Pillow>=9.3.0 in c:\users\amanda aiko\anaconda3\lib\site-packages (from pyscreeze>=0.1.21->pyautogui) (9.4.0)
# Requirement already satisfied: pyperclip in c:\users\amanda aiko\anaconda3\lib\site-packages (from mouseinfo->pyautogui) (1.8.2)
# Requirement already satisfied: EasyProcess in c:\users\amanda aiko\anaconda3\lib\site-packages (from pyscreenshot->pyscreeze>=0.1.21->pyautogui) (1.1)
# Requirement already satisfied: entrypoint2 in c:\users\amanda aiko\anaconda3\lib\site-packages (from pyscreenshot->pyscreeze>=0.1.21->pyautogui) (1.1)
# Requirement already satisfied: mss in c:\users\amanda aiko\anaconda3\lib\site-packages (from pyscreenshot->pyscreeze>=0.1.21->pyautogui) (9.0.1)
# Requirement already satisfied: pyperclip in c:\users\amanda aiko\anaconda3\lib\site-packages (1.8.2)
# amandaaiko3@hotmail.com
# Action analysis
#
# Good morning,
#
# Below are the analysis of the action ^BVSP of the last six months:
#
# Maximum quote: R$ 122560
# Minimum quote: R$ 101797
# Current quote: R$ 113155

# %% [markdown]
# Automating the send
# -find position:
# import time
# time.sleep(5)
# pyautogui.position()

# %%
#pause
pyautogui.PAUSE = 4

#open new tab
pyautogui.hotkey("ctrl", "t")

#Copy and paste email addres
pyperclip.copy("www.gmail.com")

pyautogui.hotkey("ctrl", "v")
pyautogui.hotkey("enter")

#Clicking on the write button
pyautogui.click(x=90, y=164)

#From
pyperclip.copy(From)
pyautogui.hotkey("ctrl", "v")
pyautogui.hotkey("tab")

#subject
pyperclip.copy( Subject )
pyautogui.hotkey("ctrl", "v")
pyautogui.hotkey("tab")

#email body
pyperclip.copy(Body)
pyautogui.hotkey("ctrl", "v")

#Clicking on send
pyautogui.click(x=791, y=689)

#close tab
pyautogui.hotkey("ctrl","f4")

print("email sent successfully")
# Out:
# email sent successfully
